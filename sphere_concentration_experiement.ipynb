# %% [markdown]
# <a href="https://colab.research.google.com/github/FerhatPasha/Experiments-for-Frames/blob/main/sphere_concentration_experiement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

# -----------------------------
# Parameters
# -----------------------------
d = 10
epsilon = 1.0
n_values = np.arange(20, 161, 2)

num_trials = 5000
rng = np.random.default_rng(42)

# -----------------------------
# Theoretical bound
# -----------------------------
def theoretical_bound(n, d, epsilon):
    denominator = 2*d - 2 + (2 * epsilon * (d - 1)) / 3
    return 2*d * np.exp(- n * epsilon**2 / denominator)

# -----------------------------
# Sampling from sphere of radius sqrt(d/n)
# -----------------------------
def sample_scaled_sphere_vectors(n, d, rng):
    """
    Returns an n x d matrix X whose rows are independent samples
    from the sphere S^{d-1}_{sqrt(d/n)}.
    """
    X = rng.normal(size=(n, d))
    X /= np.linalg.norm(X, axis=1, keepdims=True)
    X *= np.sqrt(d / n)
    return X

# -----------------------------
# One Monte Carlo estimate
# -----------------------------
def empirical_probability(n, d, epsilon, num_trials, rng):
    count = 0

    for _ in range(num_trials):
        X = sample_scaled_sphere_vectors(n, d, rng)

        # Frame operator S = sum_i x_i x_i^*
        S = X.T @ X

        # Operator norm of S - I_d
        op_norm = np.linalg.norm(S - np.eye(d), ord=2)

        if op_norm >= epsilon:
            count += 1

    return count / num_trials

# -----------------------------
# Run experiment
# -----------------------------
empirical_probs = []
theoretical_probs = []

for n in tqdm(n_values, desc="Running experiment"):
    emp = empirical_probability(n, d, epsilon, num_trials, rng)
    th = theoretical_bound(n, d, epsilon)

    empirical_probs.append(emp)
    theoretical_probs.append(th)

empirical_probs = np.array(empirical_probs)
theoretical_probs = np.array(theoretical_probs)

# Since probabilities cannot exceed 1, we clip only for plotting.
theoretical_probs_clipped = np.minimum(theoretical_probs, 1)

# -----------------------------
# Plot
# -----------------------------
plt.figure(figsize=(9, 5.5))

plt.plot(
    n_values,
    empirical_probs,
    marker="o",
    linestyle="-",
    color="red",
    label=r"Empirical $P(\|S-I_d\|_{\mathrm{op}} \geq \varepsilon)$"
)

plt.plot(
    n_values,
    theoretical_probs_clipped,
    linestyle="--",
    linewidth=2,
    color="turquoise",
    label="Theoretical bound"
)

plt.title(rf"$P$ vs $n$ $(d={d}, \varepsilon={epsilon})$", fontsize=14)
plt.xlabel(r"$n$", fontsize=12)
plt.ylabel(r"$P$", fontsize=12)

plt.ylim(0, 1.05)
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()
# Out:
# Running experiment:   0%|          | 0/71 [00:00<?, ?it/s]

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

# -----------------------------
# Parameters
# -----------------------------
d = 10
epsilon = 0.1

n_values = np.concatenate(([100], np.arange(500, 14001, 100)))

num_trials = 3000
rng = np.random.default_rng(42)

# -----------------------------
# Theoretical bound
# -----------------------------
def theoretical_bound(n, d, epsilon):
    denominator = 2*d - 2 + (2 * epsilon * (d - 1)) / 3
    return 2*d * np.exp(- n * epsilon**2 / denominator)

# -----------------------------
# Sampling from sphere of radius sqrt(d/n)
# -----------------------------
def sample_scaled_sphere_vectors(n, d, rng):
    X = rng.normal(size=(n, d))
    X /= np.linalg.norm(X, axis=1, keepdims=True)
    X *= np.sqrt(d / n)
    return X

# -----------------------------
# One Monte Carlo estimate
# -----------------------------
def empirical_probability(n, d, epsilon, num_trials, rng):
    count = 0

    for _ in range(num_trials):
        X = sample_scaled_sphere_vectors(n, d, rng)
        S = X.T @ X
        op_norm = np.linalg.norm(S - np.eye(d), ord=2)

        if op_norm >= epsilon:
            count += 1

    return count / num_trials

# -----------------------------
# Run experiment
# -----------------------------
empirical_probs = []
theoretical_probs = []

for n in tqdm(n_values, desc="Running experiment"):
    emp = empirical_probability(n, d, epsilon, num_trials, rng)
    th = theoretical_bound(n, d, epsilon)

    empirical_probs.append(emp)
    theoretical_probs.append(th)

empirical_probs = np.array(empirical_probs)
theoretical_probs = np.array(theoretical_probs)

# Clip theoretical bound at 1 for plotting
theoretical_probs_clipped = np.minimum(theoretical_probs, 1)

# -----------------------------
# Plot
# -----------------------------
plt.figure(figsize=(9, 5.5))

plt.plot(
    n_values,
    empirical_probs,
    marker="o",
    linestyle="-",
    color="red",
    label=r"Empirical $P(\|S-I_d\|_{\mathrm{op}} \geq \varepsilon)$"
)

plt.plot(
    n_values,
    theoretical_probs_clipped,
    linestyle="--",
    linewidth=2,
    color="turquoise",
    label="Theoretical bound"
)

plt.title(rf"$P$ vs $n$ $(d={d}, \varepsilon={epsilon})$", fontsize=14)
plt.xlabel(r"$n$", fontsize=12)
plt.ylabel(r"$P$", fontsize=12)

plt.ylim(0, 1.05)
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()
# Out:
# Running experiment:   0%|          | 0/137 [00:00<?, ?it/s]

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

# -----------------------------
# Parameters
# -----------------------------
d = 100
epsilon = 1.0

n_values = np.arange(300, 2001, 20)

num_trials = 2000
rng = np.random.default_rng(42)

# -----------------------------
# Theoretical bound
# -----------------------------
def theoretical_bound(n, d, epsilon):
    denominator = 2*d - 2 + (2 * epsilon * (d - 1)) / 3
    return 2*d * np.exp(- n * epsilon**2 / denominator)

# -----------------------------
# Sampling from sphere of radius sqrt(d/n)
# -----------------------------
def sample_scaled_sphere_vectors(n, d, rng):
    X = rng.normal(size=(n, d))
    X /= np.linalg.norm(X, axis=1, keepdims=True)
    X *= np.sqrt(d / n)
    return X

# -----------------------------
# One Monte Carlo estimate
# -----------------------------
def empirical_probability(n, d, epsilon, num_trials, rng):
    count = 0

    for _ in range(num_trials):
        X = sample_scaled_sphere_vectors(n, d, rng)
        S = X.T @ X
        op_norm = np.linalg.norm(S - np.eye(d), ord=2)

        if op_norm >= epsilon:
            count += 1

    return count / num_trials

# -----------------------------
# Run experiment
# -----------------------------
empirical_probs = []
theoretical_probs = []

for n in tqdm(n_values, desc="Running experiment"):
    emp = empirical_probability(n, d, epsilon, num_trials, rng)
    th = theoretical_bound(n, d, epsilon)

    empirical_probs.append(emp)
    theoretical_probs.append(th)

empirical_probs = np.array(empirical_probs)
theoretical_probs = np.array(theoretical_probs)

# Clip theoretical bound at 1 for plotting
theoretical_probs_clipped = np.minimum(theoretical_probs, 1)

# -----------------------------
# Plot
# -----------------------------
plt.figure(figsize=(9, 5.5))

plt.plot(
    n_values,
    empirical_probs,
    marker="o",
    linestyle="-",
    color="red",
    label=r"Empirical $P(\|S-I_d\|_{\mathrm{op}} \geq \varepsilon)$"
)

plt.plot(
    n_values,
    theoretical_probs_clipped,
    linestyle="--",
    linewidth=2,
    color="turquoise",
    label="Theoretical bound"
)

plt.title(rf"$P$ vs $n$ $(d={d}, \varepsilon={epsilon})$", fontsize=14)
plt.xlabel(r"$n$", fontsize=12)
plt.ylabel(r"$P$", fontsize=12)

plt.ylim(0, 1.05)
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()
# Out:
# Running experiment:   0%|          | 0/86 [00:00<?, ?it/s]

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

# -----------------------------
# Parameters
# -----------------------------
d = 100
epsilon = 0.1

# Dense until 50000, sparse after that
n_dense = np.arange(30000, 50001, 500)
n_sparse = np.arange(60000, 175001, 10000)
n_values = np.concatenate((n_dense, n_sparse))

num_trials = 500
rng = np.random.default_rng(42)

# -----------------------------
# Theoretical bound
# -----------------------------
def theoretical_bound(n, d, epsilon):
    denominator = 2*d - 2 + (2 * epsilon * (d - 1)) / 3
    return 2*d * np.exp(- n * epsilon**2 / denominator)

# -----------------------------
# Sampling from sphere of radius sqrt(d/n)
# -----------------------------
def sample_scaled_sphere_vectors(n, d, rng):
    X = rng.normal(size=(n, d))
    X /= np.linalg.norm(X, axis=1, keepdims=True)
    X *= np.sqrt(d / n)
    return X

# -----------------------------
# One Monte Carlo estimate
# -----------------------------
def empirical_probability(n, d, epsilon, num_trials, rng):
    count = 0

    for _ in range(num_trials):
        X = sample_scaled_sphere_vectors(n, d, rng)
        S = X.T @ X
        op_norm = np.linalg.norm(S - np.eye(d), ord=2)

        if op_norm >= epsilon:
            count += 1

    return count / num_trials

# -----------------------------
# Run experiment
# -----------------------------
empirical_probs = []
theoretical_probs = []

for n in tqdm(n_values, desc="Running experiment"):
    emp = empirical_probability(n, d, epsilon, num_trials, rng)
    th = theoretical_bound(n, d, epsilon)

    empirical_probs.append(emp)
    theoretical_probs.append(th)

empirical_probs = np.array(empirical_probs)
theoretical_probs = np.array(theoretical_probs)

# Clip theoretical bound at 1 for plotting
theoretical_probs_clipped = np.minimum(theoretical_probs, 1)

# -----------------------------
# Plot
# -----------------------------
plt.figure(figsize=(10, 5.5))

plt.plot(
    n_values,
    empirical_probs,
    marker="o",
    markersize=4,
    linestyle="-",
    color="red",
    label=r"Empirical $P(\|S-I_d\|_{\mathrm{op}} \geq \varepsilon)$"
)

plt.plot(
    n_values,
    theoretical_probs_clipped,
    linestyle="--",
    linewidth=2,
    color="turquoise",
    label="Theoretical bound"
)

plt.title(rf"$P$ vs $n$ $(d={d}, \varepsilon={epsilon})$", fontsize=14)
plt.xlabel(r"$n$", fontsize=12)
plt.ylabel(r"$P$", fontsize=12)

plt.ylim(0, 1.05)
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()
# Out:
# Running experiment:   0%|          | 0/53 [00:00<?, ?it/s]
